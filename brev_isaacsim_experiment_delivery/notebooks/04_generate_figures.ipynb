# %% [markdown]
# # 04 – Generate Figures
#
# After running the evaluation you can generate the final figures for the paper using the analysis scripts.  This notebook calls the functions in `src.analysis.render_figures` to create Figures 6–10 from the logged data.  The figures are saved to the `figures/` directory.

# %%
from src.analysis.render_figures import render_all_figures

# Generate all figures (reads logs from data_logs and writes to figures/)
render_all_figures(data_dir='data_logs', figures_dir='figures')

print('Figures generated and saved to the figures/ directory.')
